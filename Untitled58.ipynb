# %% [markdown]
# <a href="https://colab.research.google.com/github/D-Bitman/100Daysofcode_MY/blob/main/Untitled58.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 7
b = 2
print(a % b)
# Out:
# 1

# %%
print(bool(" "))
print(bool(""))
# Out:
# True
# False

# %%
x = []
if x == False:
   print("A")
elif not x:
   print("B")
else:
   print("C")
# Out:
# B
