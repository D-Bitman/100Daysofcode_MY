# %% [markdown]
# <a href="https://colab.research.google.com/github/D-Bitman/100Daysofcode_MY/blob/main/Untitled72.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = ("p" * 2) * 3
b = ("p" * 3) * 2
print(a == b)
# Out:
# True

# %%
x = 5
y = "5"
print(x + int(y))
# Out:
# 10

# %%
Tuple = (5, 10, 20)
Tuple.insert(2, 25)
print(Tuple)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1748966254.py in <cell line: 0>()
#       1 Tuple = (5, 10, 20)
# ----> 2 Tuple.insert(2, 25)
#       3 print(Tuple)
#
# AttributeError: 'tuple' object has no attribute 'insert'

# %%
import Turtle, math

t = turtle.Turtle()
t.speed(0)
t.color("cyan")
screen = turtle.Screen()
screen.bgcolor("black")

for i in range(360):
    t.goto(math.sin(i/10)*100, i - 180)
    t.dot(3)

turtle.done()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-544907671.py in <cell line: 0>()
# ----> 1 import Turtle, math
#       2
#       3 t = turtle.Turtle()
#       4 t.speed(0)
#       5 t.color("cyan")
#
# ModuleNotFoundError: No module named 'Turtle'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
